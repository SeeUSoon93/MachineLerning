# %% [markdown]
# ### 다항회귀
# - 선형 모델의 수식에서 입력 특성에 2차 이상의 항이 포함된 경우
# - 고차항이 포함되면 데이터의 특성을 더 fit하게 맞출 수 있어 성능 개선의 여지가 있다

# %%
# 사용할 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows = 22, header = None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston = pd.DataFrame(data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# * CRIM: 지역별 범죄 발생률
# * ZN: 25,000평방피트를 초과하는 거주 지역의 비율
# * INDUS: 비상업 지역 넓이 비율
# * CHAS: 찰스강에 대한 더미 변수(강의 경계에 위치한 경우는 1, 아니면 0)
# * NOX: 일산화질소 농도
# * RM: 거주할 수 있는 방 개수
# * AGE: 1940년 이전에 건축된 소유 주택의 비율
# * DIS: 5개 주요 고용센터까지의 가중 거리
# * RAD: 고속도로 접근 용이도
# * TAX: 10,000달러당 재산세율
# * PTRATIO: 지역의 교사와 학생 수 비율
# * B: 지역의 흑인 거주 비율
# * LSTAT: 하위 계층의 비율
# * MEDV: 본인 소유의 주택 가격(중앙값)

# %%
boston.shape
# Out:
# (506, 13)

# %%
target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %%
# 훈련용 데이터와 평가용데이터로 분리
X_train,X_test, y_train, y_test = train_test_split(boston, target, test_size=0.3)

# %%
# 데이터 분포 확인
plt.figure(figsize=(5,5))
plt.scatter(X_train['LSTAT'],y_train, label = 'orginal')

# 선형회귀 모델 학습
LSTAT_model = LinearRegression()
LSTAT_model.fit(X_train[['LSTAT']], y_train)
# 선형회귀 예측결과 확인
pre = LSTAT_model.predict(X_train[['LSTAT']])
plt.scatter(X_train['LSTAT'],pre, label = 'predict', color='red')

plt.legend()
plt.xlabel("LSTAT")
plt.ylabel('PRICE')
plt.show()

# %% [markdown]
# ### 다항회귀 구현하기
# 1. 특성확장을 통해서 다항식을 만들어준다
# 2. sklearn의 PolynomialFeatures를 이용한다

# %%
# 특성확장
X_train['LSTAT x LSTAT'] = X_train['LSTAT']**2

# %%
# 모델학습
LSTAT_model2 = LinearRegression()
LSTAT_model2.fit(X_train[['LSTAT','LSTAT x LSTAT']], y_train)
# Out:
# LinearRegression()

# %%
pre2 = LSTAT_model2.predict(X_train[['LSTAT','LSTAT x LSTAT']])

# %%
# 데이터 분포 확인
plt.figure(figsize=(5,5))
plt.scatter(X_train['LSTAT'],y_train, label = 'orginal')

plt.scatter(X_train['LSTAT'],pre2, label = 'predict', color='red')

plt.legend()
plt.xlabel("LSTAT")
plt.ylabel('PRICE')
plt.show()

# %% [markdown]
# #### 다항변형기(PolynomialFeatures)를 사용하여 다항회귀 구현

# %%
# 다항변형기
polynomial_transfomer = PolynomialFeatures(2)

# %%
polynomial_data = polynomial_transfomer.fit_transform(boston)

# %%
polynomial_data.shape
# Out:
# (506, 105)

# %%
# 특성확장후 컬럼명 확인
polynomial_feature_name = polynomial_transfomer.get_feature_names_out(boston.columns)

# %%
# 문제 데이터 재생성 - polynomial을 진행한 데이터를 활용해 데이터프레임 생성
X = pd.DataFrame(polynomial_data, columns=polynomial_feature_name)

# %%
X
# Out:
#        1     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  ...  \
# 0    1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  ...
# 1    1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  ...
# 2    1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  ...
# 3    1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  ...
# 4    1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  ...
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  ...
# 502  1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  ...
# 503  1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  ...
# 504  1.0  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  ...
# 505  1.0  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  ...
#
#        TAX^2  TAX PTRATIO      TAX B  TAX LSTAT  PTRATIO^2  PTRATIO B  \
# 0    87616.0       4528.8  117482.40    1474.08     234.09   6072.570
# 1    58564.0       4307.6   96049.80    2211.88     316.84   7064.820
# 2    58564.0       4307.6   95064.86     975.26     316.84   6992.374
# 3    49284.0       4151.4   87607.86     652.68     349.69   7379.581
# 4    49284.0       4151.4   88111.80    1183.26     349.69   7422.030
# ..       ...          ...        ...        ...        ...        ...
# 501  74529.0       5733.0  107013.27    2639.91     441.00   8231.790
# 502  74529.0       5733.0  108353.70    2478.84     441.00   8334.900
# 503  74529.0       5733.0  108353.70    1539.72     441.00   8334.900
# 504  74529.0       5733.0  107411.85    1769.04     441.00   8262.450
# 505  74529.0       5733.0  108353.70    2151.24     441.00   8334.900
#
#      PTRATIO LSTAT          B^2    B LSTAT  LSTAT^2
# 0           76.194  157529.6100  1976.5620  24.8004
# 1          162.692  157529.6100  3627.6660  83.5396
# 2           71.734  154315.4089  1583.1049  16.2409
# 3           54.978  155732.8369  1160.2122   8.6436
# 4           99.671  157529.6100  2115.4770  28.4089
# ..             ...          ...        ...      ...
# 501        203.070  153656.1601  3790.5433  93.5089
# 502        190.680  157529.6100  3603.8520  82.4464
# 503        118.440  157529.6100  2238.5160  31.8096
# 504        136.080  154802.9025  2549.5560  41.9904
# 505        165.480  157529.6100  3127.5720  62.0944
#
# [506 rows x 105 columns]

# %%
target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %%
# 훈련용 데이터와 평가용데이터로 분리
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.3)

# %%
# 모델생성
linear_model = LinearRegression()

# %%
# 학습
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# 예측
pre = linear_model.predict(X_test)

# %%
# 평가
mse = mean_squared_error(pre, y_test)

# RMSE(평균 제곱근 오차)
rmse = mse **0.5
rmse
# Out:
# 4.326585427832555

# %%
# 가중치(w) .coef_
linear_model.coef_
# Out:
# array([-1.88352208e+09,  3.36931536e+00, -8.81970354e-02, -5.15089008e+00,
#         2.60020829e+01, -5.95295996e+00,  1.52865567e+01,  8.85001528e-01,
#        -6.85331809e+00,  2.60454683e+00, -3.20578311e-02,  9.76565071e-01,
#        -2.71533188e-02,  1.65520677e+00,  1.78814903e-03,  1.00988148e-01,
#         5.38785511e-02,  3.61602198e+00,  7.36958882e-01,  4.21957617e-02,
#         1.12781348e-03,  9.56460288e-02,  2.86313848e-01, -2.51688452e-02,
#         2.12018801e-01, -6.48066701e-05, -1.05834030e-04, -4.84754995e-05,
#         1.27860987e-03, -1.13021900e-01, -6.19929245e-01,  2.16405014e-02,
#        -3.17593376e-04, -1.13600617e-02, -1.23964265e-02,  6.17262657e-04,
#        -8.46100815e-03,  7.80072902e-04,  1.61617348e-04,  1.04922313e-02,
#         1.89513743e-01,  2.30254852e+00,  1.94573453e-01,  3.48365265e-03,
#         9.21890119e-02,  1.58800007e-02,  3.74775092e-04, -8.97584331e-02,
#         6.91146729e-03,  6.12645018e-02,  2.60020830e+01, -1.64534392e+01,
#        -6.74335266e+00, -9.99678845e-02,  3.66772221e+00,  1.67378526e-01,
#        -7.59816309e-03, -1.01135793e+00,  2.58008091e-02,  3.04162258e-03,
#         2.26388792e+00,  2.35888761e+00, -3.46959093e-01,  1.59320253e+01,
#        -3.33530970e+00,  2.09945741e-01, -7.48152140e+00, -1.42757610e-02,
#         7.61455911e-02,  7.13593798e-01, -8.77096925e-02, -3.86278708e-01,
#         2.04661137e-02, -1.54129988e-02, -2.84781371e-01, -4.75575067e-03,
#        -2.38519560e-01,  1.84948586e-03,  1.08998620e-02,  3.38207567e-03,
#         1.81896687e-04, -1.63272734e-02, -3.54078113e-04, -1.61788589e-02,
#         5.29280365e-01, -1.04697627e-01, -1.94708281e-03, -2.81083008e-01,
#        -6.65330322e-04,  5.95413320e-02, -1.03037306e-01,  3.74770603e-03,
#        -8.70694583e-02,  2.03574303e-03,  4.14845020e-02, -1.24911067e-05,
#         9.00691473e-03, -3.06612098e-04, -5.33922712e-03,  2.40313535e-02,
#         8.08071517e-03,  7.80322925e-02, -4.05905780e-06, -1.30569962e-03,
#         1.51735983e-02])
